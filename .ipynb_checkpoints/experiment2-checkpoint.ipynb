# %%
import numpy as np
import pandas as pd
import sklearn.datasets as sd
import sklearn.model_selection as sms
import matplotlib.pyplot as plt
import random

# %%
# 读取实验训练集和验证集
X, y = sd.load_svmlight_file('a9a.txt',n_features = 123)

# %%
y = (y==1)

# %%
# 将数据集切分为训练集和验证集
X_train, X_valid, y_train, y_valid = sms.train_test_split(X, y)

# %%
# 将稀疏矩阵转为ndarray类型
X_train = X_train.toarray()
X_valid = X_valid.toarray()
y_train = y_train.reshape(len(y_train),1)
y_valid = y_valid.reshape(len(y_valid),1)

# %%
X_train = np.concatenate((np.ones((X_train.shape[0],1)), X_train), axis = 1)
X_valid = np.concatenate((np.ones((X_valid.shape[0],1)), X_valid), axis = 1)

# %%
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((12210, 124), (4071, 124), (12210, 1), (4071, 1))

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
def sigmoid_gradient(z):
    return sigmoid(z) * (1 - sigmoid(z))

# %%
def logistic_loss(X, y ,theta):
    hx = sigmoid(X.dot(theta))
    cost = np.multiply(y, np.log(hx)) + np.multiply((1-y), np.log(1-hx))
#     cost = y*(np.log(hx)) + (1 - y)*(np.log(1 - hx))
#     reg = 0.1 * np.power(theta,2).sum()
    return -cost.mean()

# %%
def logistic_gradient(X, y, theta):
    return (sigmoid(X.dot(theta)).T - y.T).dot(X).T

# %%
theta = np.zeros((X_train.shape[1],1))
logistic_loss(X_train, y_train, theta)
# Out:
# (12210, 1) (12210, 1)
# 0.6931471805599453

# %%
def logistic_descent(X, y, theta, alpha, num_iters, batch_size, X_valid, y_valid):
    X_sample = np.matrix(random.sample(X.tolist(), batch_size))
    y_sample = np.matrix(random.sample(y.tolist(), batch_size))
    loss_train = np.zeros((num_iters,1))
    loss_valid = np.zeros((num_iters,1))
    for i in range(num_iters):
        grad = logistic_gradient(X_sample, y_sample, theta)
        theta = theta - alpha * grad
        loss_train[i] = logistic_loss(X, y, theta)
        loss_valid[i] = logistic_loss(X_valid, y_valid, theta)
    return theta, loss_train, loss_valid

# %%
def logistic_score(X, y, theta):
    hx = sigmoid(X.dot(theta))
    hx = (hx>=0.5)
    hx = (hx==y)
    return np.mean(hx)

# %%
theta = np.zeros((X_train.shape[1],1))
alpha = 0.0001
num_iters = 1000
opt_theta, loss_train, loss_valid = logistic_descent(X_train, y_train, theta, alpha, num_iters, 8, X_valid, y_valid)
loss_train.max(), loss_train.min(), loss_valid.max(), loss_valid.min()
# Out:
# (0.6928107515697284,
#  0.5826995177552134,
#  0.6928020664833784,
#  0.5776961861983035)

# %%
logistic_score(X_valid, y_valid, opt_theta)
# Out:
# 0.7681159420289855

# %%
iteration = np.arange(0, num_iters, step = 1)
fig, ax = plt.subplots(figsize = (12,8))
ax.set_title('Train vs Valid')
ax.set_xlabel('iteration')
ax.set_ylabel('loss')
ax.plot(iteration, loss_train, 'r', label='Train')
ax.plot(iteration, loss_valid, 'b', label='Valid')
plt.show()

# %%
def hinge_loss(X, y, theta):
    return np.maximum(0, 1 - np.multiply(y, X.dot(theta))).mean()

# %%
theta = np.random.random((X_train.shape[1],1))
hinge_loss(X_train, y_train, theta)
# Out:
# 0.7623259623259623

# %%
def hinge_gradient(X, y, theta):
    temp = 1 - np.multiply(y, X.dot(theta))
    print(temp)
    error = np.maximum(0, )
    grad = -X.T.dot(y)
    return 0 if error.any() == 0 else grad

# %%
def svm_descent(X, y, theta, alpha, num_iters, batch_size, X_valid, y_valid):
#     data = np.concatenate((y.reshape(y.size,1),X), axis = 1)
#     data = pd.DataFrame(data)
#     data_batch = data.sample(n = batch_size, replace=False)
#     data_batch = data_batch.values
#     X = data_batch[:,1:theta.size+1]
#     y = data_batch[:,0]
    X_sample = np.matrix(random.sample(X.tolist(), batch_size))
    y_sample = np.matrix(random.sample(y.tolist(), batch_size))
    loss_train = np.zeros((num_iters,1))
    loss_valid = np.zeros((num_iters,1))
    for i in range(num_iters):
        grad = hinge_gradient(X_sample, y_sample, theta)
        theta = theta - alpha * grad
        loss_train[i] = hinge_loss(X, y, theta)
        loss_valid[i] = hinge_loss(X_valid, y_valid, theta)
    return theta, loss_train, loss_valid

# %%
def svm_score(X, y, theta):
    hx = sigmoid(X.dot(theta))
    hx = (hx>=0.5)
    hx = (hx==y)
    return np.mean(hx)

# %%
theta = np.zeros((X_train.shape[1],1))
grad = hinge_gradient(X_train, y_train, theta)
# Out:
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]] (12210, 1)
# (124, 1)

# %%
theta = np.zeros((X_train.shape[1],1))
alpha = 0.0001
num_iters = 200
opt_theta, loss_train, loss_valid = svm_descent(X_train, y_train, theta, alpha, num_iters, X_train.shape[0], X_valid, y_valid)
loss_train.max(), loss_train.min(), loss_valid.max(), loss_valid.min()
# Out:
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]] (12210, 1)
# (124, 1)
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]] (12210, 1)
# (124, 1)
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]] (12210, 1)
# (124, 1)
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]] (12210, 1)
# (124, 1)
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]] (12210, 1)
# (124, 1)
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]] (12210, 1)
# (124, 1)
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]] (12210, 1)
# (124, 1)
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]] (12210, 1)
# (124, 1)
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]] (12210, 1)
# (124, 1)
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]] (12210, 1)
# (124, 1)
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]] (12210, 1)
# (124, 1)
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]] (12210, 1)
# (124, 1)
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
# ...

# %%
theta = np.zeros((X_train.shape[1],1))
alpha = 0.0001
num_iters = 200
opt_theta, loss_train = svm_descent(X_valid, y_valid, theta, alpha, num_iters, X_valid.shape[0])
loss_valid.max(), loss_valid.min()
# Out:
# (0.5495924550822722, 0.3362274114633319)

# %%
iteration = np.arange(0, num_iters, step = 1)
fig, ax = plt.subplots(figsize = (12,8))
ax.set_title('Train vs Valid')
ax.set_xlabel('iteration')
ax.set_ylabel('loss')
ax.plot(iteration, loss_train, 'r')
ax.plot(iteration, loss_valid, 'b')
plt.show()

# %%
a = np.array([-1,2,3,4])
np.maximum(a,0)
# Out:
# array([0, 2, 3, 4])
