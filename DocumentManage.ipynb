# %%
import numpy as np
import pandas as pd
import os

# %%
temp = pd.read_csv('ws15xz12.csv')

# %%
temp.head()
# Out:
#    No documentListNo                       案卷名              文件级档号  \
# 0   7  2000-WS15-003  外国留学生入学申请表、审批表、录取通知书、成绩单  2000-ws15-003-002
# 1   8  2000-WS15-003  外国留学生入学申请表、审批表、录取通知书、成绩单  2000-ws15-003-003
# 2   9  2000-WS15-003  外国留学生入学申请表、审批表、录取通知书、成绩单  2000-ws15-003-004
# 3  10  2000-WS15-003  外国留学生入学申请表、审批表、录取通知书、成绩单  2000-ws15-003-005
# 4  11  2000-WS15-003  外国留学生入学申请表、审批表、录取通知书、成绩单  2000-ws15-003-006
#
#                                       文件名  扫描或挂接   备注
# 0               法国留学生林伯德来我校学习汉语的签证申请表及审批表  扫描并挂接  NaN
# 1               韩国留学生金永根来我校学习汉语的签证申请表及审批表  扫描并挂接  NaN
# 2   日本留学生ARAI RINA(新井利奈)来我校学习汉语的签证申请表及审批表     挂接  NaN
# 3  日本留学生OSAWA AKANE(大泽茜）来我校学习汉语的签证申请表及审批表     挂接  NaN
# 4               韩国留学生朴美正来我校学习汉语的签证申请表及审批表     挂接  NaN

# %%
filepath = 'C:\\Users\\郑炜俊\\Desktop\\要看的书\\'
doc_list = os.listdir(filepath)

# %%
doc_list_df = pd.DataFrame(doc_list)

# %%
doc_list_df.head()
# Out:
#                                      0
# 0                                 .git
# 1                       Androidmap.pdf
# 2  Building+a+REST+API+with+Spring.pdf
# 3           Deeplearning深度学习笔记v5.6.pdf
# 4                            Git手册.pdf

# %%
temp.append(doc_list_df)
# Out:
#                                       0    No documentListNo   备注  扫描或挂接  \
# 0                                   NaN   7.0  2000-WS15-003  NaN  扫描并挂接
# 1                                   NaN   8.0  2000-WS15-003  NaN  扫描并挂接
# 2                                   NaN   9.0  2000-WS15-003  NaN     挂接
# 3                                   NaN  10.0  2000-WS15-003  NaN     挂接
# 4                                   NaN  11.0  2000-WS15-003  NaN     挂接
# 5                                   NaN  12.0  2000-WS15-003  NaN     挂接
# 6                                   NaN  13.0  2000-WS15-003  NaN     挂接
# 7                                   NaN   6.0  2000-WS15-002  NaN     挂接
# 8                                   NaN   1.0  2000-WS15-001  NaN     挂接
# 9                                   NaN   2.0  2000-WS15-001  NaN     挂接
# 10                                  NaN   3.0  2000-WS15-001  NaN     挂接
# 11                                  NaN   4.0  2000-WS15-001  NaN     挂接
# ...
